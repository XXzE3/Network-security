# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pymongo
import os, sys

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
uri = os.getenv("MONGO_DB_URL")
client = pymongo.MongoClient(uri)
client
# Out:
# MongoClient(host=['cluster0-shard-00-00.pm28o.mongodb.net:27017', 'cluster0-shard-00-02.pm28o.mongodb.net:27017', 'cluster0-shard-00-01.pm28o.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', appname='Cluster0', authsource='admin', replicaset='atlas-135j4s-shard-0', tls=True)

# %%
mydb = client['NetworkSecurity']
collection = mydb['NetworkData']
collection
# Out:
# Collection(Database(MongoClient(host=['cluster0-shard-00-00.pm28o.mongodb.net:27017', 'cluster0-shard-00-02.pm28o.mongodb.net:27017', 'cluster0-shard-00-01.pm28o.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', appname='Cluster0', authsource='admin', replicaset='atlas-135j4s-shard-0', tls=True), 'NetworkSecurity'), 'NetworkData')

# %%
data = collection.find()
data_list = [i for i in data]
print(len(data_list))
# Out:
# 11055

# %%
df = pd.DataFrame(data_list)
df.head()
# Out:
#                         _id  having_IP_Address  URL_Length  \
# 0  66c78bcda329a93a28e7a5c5                 -1           1
# 1  66c78bcda329a93a28e7a5c6                  1           1
# 2  66c78bcda329a93a28e7a5c7                  1           0
# 3  66c78bcda329a93a28e7a5c8                  1           0
# 4  66c78bcda329a93a28e7a5c9                  1           0
#
#    Shortining_Service  having_At_Symbol  double_slash_redirecting  \
# 0                   1                 1                        -1
# 1                   1                 1                         1
# 2                   1                 1                         1
# 3                   1                 1                         1
# 4                  -1                 1                         1
#
#    Prefix_Suffix  having_Sub_Domain  SSLfinal_State  \
# 0             -1                 -1              -1
# 1             -1                  0               1
# ...

# %%
df.drop(columns='_id', inplace = True)

# %%
df.columns
# Out:
# Index(['having_IP_Address', 'URL_Length', 'Shortining_Service',
#        'having_At_Symbol', 'double_slash_redirecting', 'Prefix_Suffix',
#        'having_Sub_Domain', 'SSLfinal_State', 'Domain_registeration_length',
#        'Favicon', 'port', 'HTTPS_token', 'Request_URL', 'URL_of_Anchor',
#        'Links_in_tags', 'SFH', 'Submitting_to_email', 'Abnormal_URL',
#        'Redirect', 'on_mouseover', 'RightClick', 'popUpWidnow', 'Iframe',
#        'age_of_domain', 'DNSRecord', 'web_traffic', 'Page_Rank',
#        'Google_Index', 'Links_pointing_to_page', 'Statistical_report',
#        'Result'],
#       dtype='object')

# %%
df.shape
# Out:
# (11055, 31)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11055 entries, 0 to 11054
# Data columns (total 31 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   having_IP_Address            11055 non-null  int64
#  1   URL_Length                   11055 non-null  int64
#  2   Shortining_Service           11055 non-null  int64
#  3   having_At_Symbol             11055 non-null  int64
#  4   double_slash_redirecting     11055 non-null  int64
#  5   Prefix_Suffix                11055 non-null  int64
#  6   having_Sub_Domain            11055 non-null  int64
#  7   SSLfinal_State               11055 non-null  int64
#  8   Domain_registeration_length  11055 non-null  int64
#  9   Favicon                      11055 non-null  int64
#  10  port                         11055 non-null  int64
#  11  HTTPS_token                  11055 non-null  int64
#  12  Request_URL                  11055 non-null  int64
# ...

# %%
df.describe()
# Out:
#        having_IP_Address    URL_Length  Shortining_Service  having_At_Symbol  \
# count       11055.000000  11055.000000        11055.000000      11055.000000
# mean            0.313795     -0.633198            0.738761          0.700588
# std             0.949534      0.766095            0.673998          0.713598
# min            -1.000000     -1.000000           -1.000000         -1.000000
# 25%            -1.000000     -1.000000            1.000000          1.000000
# 50%             1.000000     -1.000000            1.000000          1.000000
# 75%             1.000000     -1.000000            1.000000          1.000000
# max             1.000000      1.000000            1.000000          1.000000
#
#        double_slash_redirecting  Prefix_Suffix  having_Sub_Domain  \
# count              11055.000000   11055.000000       11055.000000
# mean                   0.741474      -0.734962           0.063953
# std                    0.671011       0.678139           0.817518
# ...

# %%
df.nunique()
# Out:
# having_IP_Address              2
# URL_Length                     3
# Shortining_Service             2
# having_At_Symbol               2
# double_slash_redirecting       2
# Prefix_Suffix                  2
# having_Sub_Domain              3
# SSLfinal_State                 3
# Domain_registeration_length    2
# Favicon                        2
# port                           2
# HTTPS_token                    2
# Request_URL                    2
# URL_of_Anchor                  3
# Links_in_tags                  3
# SFH                            3
# Submitting_to_email            2
# Abnormal_URL                   2
# Redirect                       2
# on_mouseover                   2
# RightClick                     2
# popUpWidnow                    2
# Iframe                         2
# age_of_domain                  2
# DNSRecord                      2
# web_traffic                    3
# Page_Rank                      2
# Google_Index                   2
# ...

# %%
df['URL_Length'].value_counts()
# Out:
# URL_Length
# -1    8960
#  1    1960
#  0     135
# Name: count, dtype: int64

# %%
df['Request_URL'].value_counts()
# Out:
# Request_URL
#  1    6560
# -1    4495
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# having_IP_Address              0
# URL_Length                     0
# Shortining_Service             0
# having_At_Symbol               0
# double_slash_redirecting       0
# Prefix_Suffix                  0
# having_Sub_Domain              0
# SSLfinal_State                 0
# Domain_registeration_length    0
# Favicon                        0
# port                           0
# HTTPS_token                    0
# Request_URL                    0
# URL_of_Anchor                  0
# Links_in_tags                  0
# SFH                            0
# Submitting_to_email            0
# Abnormal_URL                   0
# Redirect                       0
# on_mouseover                   0
# RightClick                     0
# popUpWidnow                    0
# Iframe                         0
# age_of_domain                  0
# DNSRecord                      0
# web_traffic                    0
# Page_Rank                      0
# Google_Index                   0
# ...

# %%
df[df.duplicated()]
# Out:
#        having_IP_Address  URL_Length  Shortining_Service  having_At_Symbol  \
# 180                    1          -1                   1                 1
# 203                    1          -1                   1                 1
# 323                    1          -1                   1                 1
# 364                    1          -1                   1                 1
# 381                    1          -1                   1                 1
# ...                  ...         ...                 ...               ...
# 11047                 -1          -1                   1                 1
# 11050                  1          -1                   1                -1
# 11051                 -1           1                   1                -1
# 11052                  1          -1                   1                 1
# 11053                 -1          -1                   1                 1
#
#        double_slash_redirecting  Prefix_Suffix  having_Sub_Domain  \
# ...

# %%
df['Result'].value_counts()
# Out:
# Result
#  1    6157
# -1    4898
# Name: count, dtype: int64

# %%
df['Result'].replace(-1,0,inplace =  True)

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split

# %%
x = df.drop(columns='Result')
y = df['Result']
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2)

# %%
x_train.shape
# Out:
# (8844, 30)

# %%
model = XGBClassifier(n_estimator = 200, learning_rate = 0.1)

# %%
model.fit(x_train,y_train)
# Out:
# d:\Data science\MLOps(krish naik)\Network security\networkproject\lib\site-packages\xgboost\core.py:158: UserWarning: [03:33:19] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "n_estimator" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
# ...

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import f1_score,accuracy_score

# %%
f1 = f1_score(y_test, y_pred)
f1
# Out:
# np.float64(0.9691629955947136)

# %%
acc = accuracy_score(y_test,y_pred)
acc
# Out:
# 0.9651741293532339
